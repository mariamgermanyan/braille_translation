# %% [markdown]
# # Resources

# %% [markdown]
# https://songyang0716.github.io/2017/06/an-implementation-of-noisy-channel-model/

# %% [markdown]
# # Imports

# %%
import matplotlib.pyplot as plt
import PIL
import numpy as np
from PIL import Image
import os
import glob

from matplotlib import cm

# %matplotlib inline

# Import a bunch of libraries.
import time
from sklearn.cluster import KMeans
from matplotlib.ticker import MultipleLocator
from sklearn.pipeline import Pipeline
from sklearn.datasets import fetch_openml
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn.linear_model import LinearRegression
from sklearn.naive_bayes import BernoulliNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from shutil import copyfile
from pybraille import convertText

from nltk.corpus import words
import collections
import enchant
import csv
import math, collections
import pandas as pd
import re
import itertools
import nltk
import nltk.data
nltk.download('words')
import string
nltk.download('brown')
from tensorflow.keras.preprocessing import image
from scipy import ndimage, misc
import cv2

# Set the randomizer seed so results are the same each time.
np.random.seed(0)
# Out:
# [nltk_data] Downloading package words to /Users/mariam/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package brown to /Users/mariam/nltk_data...
# [nltk_data]   Package brown is already up-to-date!

# %% [markdown]
# # Approach 1: Preprocessing Data at the Sentence Level
# ### Reading in sentences that we created

# %%
# path = "./266 Photos/sentences"
# def read_files(path):

#     all_files = glob.glob(path + "/*.png")

#     sentences = []
#     images = []
    
#     for filename in all_files:
#         img = Image.open(filename)
        
#         sentence = os.path.basename(os.path.normpath(os.path.splitext(filename)[0]))
#         sentences.append(sentence)

#         images.append(img)

#     return sentences, images
# sentences, images = read_files(path)

# %%
# path = os.getcwd() + '/test_words/'
# all_files = glob.glob(path + "/*.png")
# len(all_files)

# %%
path = os.getcwd() + '/test_words'
def read_files(path):

    all_files = glob.glob(path + "/*.png")

    sentences = []
    images = []
    
    for filename in all_files:
        with Image.open(filename) as img:
            sentence = os.path.basename(os.path.normpath(os.path.splitext(filename)[0]))
            sentences.append(sentence)
            first = np.array(img)[:,:,0].T[0:28].T
            second = np.array(img)[:,:,0].T[28:57].T
            third = np.array(img)[:,:,0].T[56:].T
            images.append([Image.fromarray(first), Image.fromarray(second), Image.fromarray(third)])
    return sentences, images

# %%
path = os.getcwd() + '/test_words'
def read_files(path):

    all_files = glob.glob(path + "/*.png")

    sentences = []
    images = []
    
    for filename in all_files:
        with Image.open(filename) as img:
            sentence = os.path.basename(os.path.normpath(os.path.splitext(filename)[0]))
            sentences.append(sentence)
            first = np.array(img)[:,:,0].T[0:28].T
            second = np.array(img)[:,:,0].T[28:57].T
            third = np.array(img)[:,:,0].T[56:].T
            first = cv2.cvtColor(first, cv2.COLOR_GRAY2BGR)
            second = cv2.cvtColor(second, cv2.COLOR_GRAY2BGR)
            third = cv2.cvtColor(third, cv2.COLOR_GRAY2BGR)
            images.append([Image.fromarray(first), Image.fromarray(second), Image.fromarray(third)])
    return sentences, images

# %%
english_words, braille_images = read_files(path)

# %%
np.shape(braille_images[0][0])
# Out:
# (28, 28, 3)

# %%
plt.imshow(images[1]), sentences[1]
# Out:
# (<matplotlib.image.AxesImage at 0x7f85d1312650>,
#  'The smoke was high in the sky')

# %% [markdown]
# Things to consider with this approach:
# - Abbreviations within braille
#     - would working at the character level help solve this?
#         - ie translate abbreviations first, then character by character
# - Need more data
#     - what will happen with unseen data?

# %% [markdown]
# # Approach 2: Preprocessing Data at the character level
# ### Split the images from above to a character by character basis

# %% [markdown]
# # Pre-existing Model Training on kaggle data¶

# %%
# Get the images into corresponding folders.

# %%
os.mkdir('./images/')

alpha = 'a'
for i in range(0, 26): 
    os.mkdir('./images/' + alpha)
    alpha = chr(ord(alpha) + 1)

rootdir = os.getcwd() + '/archive/Braille Dataset/Braille Dataset/'
for file in os.listdir(rootdir):
    letter = file[0]
    copyfile(rootdir+file, './images/' + letter + '/' + file)

# %%
# path = os.getcwd() + '/archive/Braille Dataset/Braille Dataset/'
# all_files = glob.glob(path + "/*.jpg") 
# for file_path in all_files:
#     if file_path[-7:-4] == 'rot':
#         os.remove(file_path)
# path = os.getcwd() + '/archive/Braille Dataset/Braille Dataset/'
# all_files = glob.glob(path + "/*.jpg") 
# for file_path in all_files:
#     if file_path[-7:-4] == 'dim':
#         os.remove(file_path)

# %%
from keras.preprocessing.image import ImageDataGenerator
datagen = ImageDataGenerator(validation_split=0.3)

train_generator = datagen.flow_from_directory('./images/',
                                              target_size=(28,28),
                                              subset='training')

val_generator = datagen.flow_from_directory('./images/',
                                            target_size=(28,28),
                                            subset='validation')
# Out:
# Found 364 images belonging to 26 classes.
# Found 156 images belonging to 26 classes.

# %%
# kaggle data
# np.random.seed(0)
# test_files = np.random.choice(val_generator.filenames, size = 49)
# test_path = './images/'
# test_actual = [i[0] for i in test_files]

# %%
# for i in test_files:
#     if i in val_generator.filenames:
#         val_generator.filenames.remove(i)

# %%
from keras import backend as K
from keras import layers as L
from keras.models import Model,load_model
from keras.regularizers import l2
from keras.callbacks import ModelCheckpoint,ReduceLROnPlateau,EarlyStopping

K.clear_session()

model_ckpt = ModelCheckpoint('BrailleNet.h5',save_best_only=True)
reduce_lr = ReduceLROnPlateau(patience=8,verbose=0)
early_stop = EarlyStopping(patience=15,verbose=1)

entry = L.Input(shape=(28,28,3))
x = L.SeparableConv2D(64,(3,3),activation='relu')(entry)
x = L.MaxPooling2D((2,2))(x)
x = L.SeparableConv2D(128,(3,3),activation='relu')(x)
x = L.MaxPooling2D((2,2))(x)
x = L.SeparableConv2D(256,(2,2),activation='relu')(x)
x = L.GlobalMaxPooling2D()(x)
x = L.Dense(256)(x)
x = L.LeakyReLU()(x)
x = L.Dense(64,kernel_regularizer=l2(2e-4))(x)
x = L.LeakyReLU()(x)
x = L.Dense(26,activation='softmax')(x)

model = Model(entry,x)
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

history = model.fit_generator(train_generator,
                              validation_data=val_generator,
                              epochs=50,
                              callbacks=[model_ckpt,reduce_lr,early_stop],
                              verbose=1)
# Out:
# Epoch 1/50
# 12/12 [==============================] - 1s 72ms/step - loss: 3.3193 - accuracy: 0.0247 - val_loss: 3.2728 - val_accuracy: 0.0449
# Epoch 2/50
# 12/12 [==============================] - 0s 39ms/step - loss: 3.2732 - accuracy: 0.0302 - val_loss: 3.2643 - val_accuracy: 0.0385
# Epoch 3/50
# 12/12 [==============================] - 1s 49ms/step - loss: 3.2515 - accuracy: 0.0522 - val_loss: 3.2476 - val_accuracy: 0.0513
# Epoch 4/50
# 12/12 [==============================] - 1s 46ms/step - loss: 3.2176 - accuracy: 0.0659 - val_loss: 3.2069 - val_accuracy: 0.1282
# Epoch 5/50
# 12/12 [==============================] - 1s 45ms/step - loss: 3.1420 - accuracy: 0.1374 - val_loss: 3.1103 - val_accuracy: 0.1090
# Epoch 6/50
# 12/12 [==============================] - 1s 45ms/step - loss: 2.9242 - accuracy: 0.1731 - val_loss: 2.8662 - val_accuracy: 0.2051
# Epoch 7/50
# 12/12 [==============================] - 0s 40ms/step - loss: 2.6514 - accuracy: 0.1868 - val_loss: 2.7810 - val_accuracy: 0.1603
# Epoch 8/50
# 12/12 [==============================] - 1s 45ms/step - loss: 2.4436 - accuracy: 0.2473 - val_loss: 2.5814 - val_accuracy: 0.2885
# Epoch 9/50
# 12/12 [==============================] - 1s 51ms/step - loss: 2.1303 - accuracy: 0.3516 - val_loss: 2.1977 - val_accuracy: 0.3077
# Epoch 10/50
# 12/12 [==============================] - 0s 40ms/step - loss: 1.8245 - accuracy: 0.4341 - val_loss: 1.9870 - val_accuracy: 0.4038
# Epoch 11/50
# 12/12 [==============================] - 1s 47ms/step - loss: 1.4757 - accuracy: 0.5467 - val_loss: 1.8126 - val_accuracy: 0.4744
# Epoch 12/50
# 12/12 [==============================] - 1s 49ms/step - loss: 1.1368 - accuracy: 0.6566 - val_loss: 1.5563 - val_accuracy: 0.5000
# Epoch 13/50
# 12/12 [==============================] - 1s 47ms/step - loss: 0.9898 - accuracy: 0.6648 - val_loss: 1.5999 - val_accuracy: 0.5256
# Epoch 14/50
# 12/12 [==============================] - 1s 43ms/step - loss: 0.9460 - accuracy: 0.6813 - val_loss: 1.6237 - val_accuracy: 0.4872
# Epoch 15/50
# 12/12 [==============================] - 1s 64ms/step - loss: 0.7204 - accuracy: 0.7610 - val_loss: 1.2901 - val_accuracy: 0.5641
# Epoch 16/50
# 12/12 [==============================] - 0s 36ms/step - loss: 0.5148 - accuracy: 0.8352 - val_loss: 1.2487 - val_accuracy: 0.5897
# Epoch 17/50
# 12/12 [==============================] - 0s 34ms/step - loss: 0.3745 - accuracy: 0.8901 - val_loss: 1.2220 - val_accuracy: 0.6474
# Epoch 18/50
# 12/12 [==============================] - 0s 36ms/step - loss: 0.3535 - accuracy: 0.8929 - val_loss: 1.1064 - val_accuracy: 0.6474
# Epoch 19/50
# 12/12 [==============================] - 0s 30ms/step - loss: 0.2691 - accuracy: 0.9203 - val_loss: 1.2833 - val_accuracy: 0.6026
# Epoch 20/50
# 12/12 [==============================] - 0s 40ms/step - loss: 0.3395 - accuracy: 0.8874 - val_loss: 1.1565 - val_accuracy: 0.6603
# Epoch 21/50
# 12/12 [==============================] - 0s 38ms/step - loss: 0.2308 - accuracy: 0.9451 - val_loss: 1.1076 - val_accuracy: 0.6667
# Epoch 22/50
# 12/12 [==============================] - 0s 38ms/step - loss: 0.1574 - accuracy: 0.9753 - val_loss: 1.0055 - val_accuracy: 0.6859
# Epoch 23/50
# 12/12 [==============================] - 0s 37ms/step - loss: 0.1288 - accuracy: 0.9835 - val_loss: 0.8902 - val_accuracy: 0.7500
# Epoch 24/50
# 12/12 [==============================] - 0s 35ms/step - loss: 0.1715 - accuracy: 0.9478 - val_loss: 0.9462 - val_accuracy: 0.7564
# Epoch 25/50
# 12/12 [==============================] - 1s 42ms/step - loss: 0.1341 - accuracy: 0.9670 - val_loss: 1.1506 - val_accuracy: 0.6795
# Epoch 26/50
# 12/12 [==============================] - 1s 47ms/step - loss: 0.0885 - accuracy: 0.9890 - val_loss: 0.8721 - val_accuracy: 0.7692
# Epoch 27/50
# 12/12 [==============================] - 1s 43ms/step - loss: 0.0608 - accuracy: 0.9973 - val_loss: 0.8311 - val_accuracy: 0.7564
# Epoch 28/50
# 12/12 [==============================] - 1s 45ms/step - loss: 0.0494 - accuracy: 1.0000 - val_loss: 0.8234 - val_accuracy: 0.7692
# Epoch 29/50
# 12/12 [==============================] - 0s 32ms/step - loss: 0.0390 - accuracy: 1.0000 - val_loss: 0.8214 - val_accuracy: 0.7692
# Epoch 30/50
# 12/12 [==============================] - 0s 34ms/step - loss: 0.0351 - accuracy: 1.0000 - val_loss: 0.8348 - val_accuracy: 0.8077
# Epoch 31/50
# 12/12 [==============================] - 0s 32ms/step - loss: 0.0327 - accuracy: 1.0000 - val_loss: 0.8172 - val_accuracy: 0.8013
# Epoch 32/50
# 12/12 [==============================] - 0s 31ms/step - loss: 0.0315 - accuracy: 1.0000 - val_loss: 0.8150 - val_accuracy: 0.7949
# Epoch 33/50
# 12/12 [==============================] - 0s 35ms/step - loss: 0.0285 - accuracy: 1.0000 - val_loss: 0.8119 - val_accuracy: 0.8077
# Epoch 34/50
# 12/12 [==============================] - 0s 32ms/step - loss: 0.0283 - accuracy: 1.0000 - val_loss: 0.8238 - val_accuracy: 0.7821
# Epoch 35/50
# 12/12 [==============================] - 0s 29ms/step - loss: 0.0274 - accuracy: 1.0000 - val_loss: 0.8359 - val_accuracy: 0.7821
# Epoch 36/50
# 12/12 [==============================] - 0s 32ms/step - loss: 0.0270 - accuracy: 1.0000 - val_loss: 0.8275 - val_accuracy: 0.7885
# Epoch 37/50
# 12/12 [==============================] - 0s 28ms/step - loss: 0.0267 - accuracy: 1.0000 - val_loss: 0.8380 - val_accuracy: 0.7949
# Epoch 38/50
# 12/12 [==============================] - 0s 29ms/step - loss: 0.0264 - accuracy: 1.0000 - val_loss: 0.8503 - val_accuracy: 0.7692
# Epoch 39/50
# 12/12 [==============================] - 0s 30ms/step - loss: 0.0262 - accuracy: 1.0000 - val_loss: 0.8441 - val_accuracy: 0.7885
# Epoch 40/50
# 12/12 [==============================] - 0s 30ms/step - loss: 0.0259 - accuracy: 1.0000 - val_loss: 0.8567 - val_accuracy: 0.7821
# Epoch 41/50
# 12/12 [==============================] - 0s 28ms/step - loss: 0.0256 - accuracy: 1.0000 - val_loss: 0.8503 - val_accuracy: 0.7821
# Epoch 42/50
# 12/12 [==============================] - 0s 31ms/step - loss: 0.0255 - accuracy: 1.0000 - val_loss: 0.8508 - val_accuracy: 0.7821
# Epoch 43/50
# 12/12 [==============================] - 1s 46ms/step - loss: 0.0255 - accuracy: 1.0000 - val_loss: 0.8516 - val_accuracy: 0.7821
# Epoch 44/50
# 12/12 [==============================] - 1s 45ms/step - loss: 0.0254 - accuracy: 1.0000 - val_loss: 0.8531 - val_accuracy: 0.7756
# Epoch 45/50
# 12/12 [==============================] - 0s 33ms/step - loss: 0.0254 - accuracy: 1.0000 - val_loss: 0.8550 - val_accuracy: 0.7756
# Epoch 46/50
# 12/12 [==============================] - 0s 35ms/step - loss: 0.0254 - accuracy: 1.0000 - val_loss: 0.8558 - val_accuracy: 0.7756
# Epoch 47/50
# 12/12 [==============================] - 1s 45ms/step - loss: 0.0254 - accuracy: 1.0000 - val_loss: 0.8554 - val_accuracy: 0.7756
# Epoch 48/50
# 12/12 [==============================] - 1s 58ms/step - loss: 0.0253 - accuracy: 1.0000 - val_loss: 0.8566 - val_accuracy: 0.7756
# Epoch 00048: early stopping

# %%
alphabet = []
alpha = 'a'
for i in range(0, 26): 
    alphabet.append(alpha)
    alpha = chr(ord(alpha) + 1)

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'], label='train loss')
plt.plot(history.history['val_loss'], label='val loss')
plt.legend()
plt.show()
plt.savefig('LossVal_loss')

# plot the accuracy
plt.plot(history.history['accuracy'], label='train acc')
plt.plot(history.history['val_accuracy'], label='val acc')
plt.legend()
plt.show()
plt.savefig('AccVal_acc')

# %%
curr = './266 Photos/test/' 
actual = []
predictions = []
num_correct = 0
total = 0
for image_path in os.listdir(curr):
    if image_path[-3:] == 'png':
        actual.append(image_path[0])
        img=image.load_img(curr + image_path)
#         plt.imshow(img)
#         plt.show()
        x=image.img_to_array(img)
        x=np.expand_dims(x,axis=0)
        prediction=np.argmax(model.predict(x), axis=1)[0]
        predictions.append(alphabet[prediction])
        if alphabet[prediction] == image_path[0]:
            num_correct += 1
        total += 1    
        print('^ predicted: ', alphabet[prediction], 'actual: ',image_path[0], '^')
print('accuracy: ', num_correct/total)
# Out:
# ^ predicted:  a actual:  k ^
# ^ predicted:  j actual:  j ^
# ^ predicted:  g actual:  h ^
# ^ predicted:  s actual:  i ^
# ^ predicted:  j actual:  z ^
# ^ predicted:  n actual:  m ^
# ^ predicted:  q actual:  l ^
# ^ predicted:  j actual:  y ^
# ^ predicted:  n actual:  n ^
# ^ predicted:  o actual:  o ^
# ^ predicted:  k actual:  x ^
# ^ predicted:  u actual:  u ^
# ^ predicted:  g actual:  b ^
# ^ predicted:  g actual:  c ^
# ^ predicted:  j actual:  t ^
# ^ predicted:  s actual:  v ^
# ^ predicted:  c actual:  a ^
# ^ predicted:  j actual:  w ^
# ^ predicted:  g actual:  d ^
# ^ predicted:  s actual:  s ^
# ^ predicted:  s actual:  r ^
# ^ predicted:  o actual:  e ^
# ^ predicted:  g actual:  g ^
# ^ predicted:  q actual:  p ^
# ^ predicted:  q actual:  q ^
# ^ predicted:  g actual:  f ^
# accuracy:  0.2692307692307692

# %% [markdown]
# # 26 characters * 20 different images of different augmentation values

# %%
def english_to_braille(word, test = True, show = True):
    indexes = []
    word_images = []
    word_arrays = []
    if test:
        path = os.getcwd() + '/266 Photos/test/'
        
        all_files = glob.glob(path + "/*.png")    
        all_files = np.sort(all_files)
        for char in word:
            
            item = all_files[alphabet.index(char)]
            word_images.append(item)
            
            img = Image.open(item)
            word_arrays.append(img)
            if show:
                print(os.path.basename(os.path.normpath(os.path.splitext(item)[0])))
                plt.imshow(img)
                plt.show()
        
    else:
        path = os.getcwd() + '/archive/Braille Dataset/Braille Dataset/'
        all_files = glob.glob(path + "/*.jpg")    
        all_files = np.sort(all_files)
        for char in word:
            indexes.append(alphabet.index(char))
        for index in indexes:
            random_number = np.random.choice(np.arange(index * 20, (index + 1) * 20))
            word_images.append(all_files[random_number])
        for item in word_images:
            
            img = Image.open(item)
            word_arrays.append(img)
            if show:
                print(os.path.basename(os.path.normpath(os.path.splitext(item)[0])))
                plt.imshow(img)
                plt.show()
    return word_images

# %%
the = english_to_braille('the', test = False)
# Out:
# t1.JPG9whs
# h1.JPG2whs
# e1.JPG7whs

# %%
the = english_to_braille('the', test = True)
# Out:
# t
# h
# e

# %%
corpus = nltk.corpus.brown
len(corpus.words())
# Out:
# 1161192

# %%
from nltk.corpus import words
laplaceUniCharCounts = collections.defaultdict(lambda: 0)
laplaceBiCharCounts = collections.defaultdict(lambda: 0)
laplaceTriCharCounts = collections.defaultdict(lambda: 0)
laplaceQuadCharCounts = collections.defaultdict(lambda: 0)
totalUni = 0
totalBi = 0
totalTri = 0
words_data = list([i.lower() for i in corpus.words()])
filtered_words = []
remove_items = string.punctuation + '0123456789'
for word in words_data:
    no_punctuation = True
    for item in remove_items:
        if item in word:
            no_punctuation = False
        if no_punctuation == False:
            break
    if no_punctuation:
        filtered_words.append(word)
words = [list(i) for i in filtered_words]
#remove characters 

for word in words:
# better results without it
#         word.insert(0, '<w>')
        word.append('</w>')
        for i in range(len(word)):
            token1 = word[i]
            laplaceUniCharCounts[token1] += 1
            #totalUni += 1
        for i in range(len(word)-1):
            token1 = word[i]
            token2 = word[i + 1]
            laplaceBiCharCounts[token1 + token2] += 1
            #totalBi += 1
        for i in range(len(word)-2):
            token1 = word[i]
            token2 = word[i + 1]
            token3 = word[i + 2]
            laplaceTriCharCounts[token1 + token2 + token3] += 1
        for i in range(len(word)-3):
            
            token1 = word[i]
            token2 = word[i + 1]
            token3 = word[i + 2]
            token4 = word[i + 3]
#             if token1 + token2 + token3 == 'bbb':
#                 print(word)
            laplaceQuadCharCounts[token1 + token2 + token3 + token4] += 1
            #totalTri += 1
#         totalUni += 1
#         totalBi += 1
#         totalTri += 1
totalUni = sum(laplaceUniCharCounts.values())
totalBi = sum(laplaceBiCharCounts.values())
totalTri = sum(laplaceTriCharCounts.values())
totalQuad = sum(laplaceQuadCharCounts.values())

# %%
def language_model(word):
    first_char = word[0]
    sec_char = word[1]
    third_char = word[2]
    fourth_char = '</w>'
    p1 = laplaceUniCharCounts[first_char]/totalUni
    p2 = laplaceBiCharCounts[first_char+sec_char]/sum([value if key.startswith(first_char) else 0 for key, value in laplaceBiCharCounts.items()])
    
    if laplaceTriCharCounts[first_char+sec_char+third_char] != 0:
        p3 = laplaceTriCharCounts[first_char+sec_char+third_char]/sum([value if key.startswith(first_char+sec_char) else 0 for key, value in laplaceTriCharCounts.items()])
    else:
        p3 = 0
    if laplaceQuadCharCounts[first_char+sec_char+third_char+ fourth_char] != 0:
        p4 = laplaceQuadCharCounts[first_char+sec_char+third_char+ fourth_char]/sum([value if key.startswith(first_char+sec_char+ third_char) else 0 for key, value in laplaceQuadCharCounts.items()])
    else:
        p4 = 0
    return [p1, p2, p3, p4]

# %%
dictionary = collections.Counter(filtered_words)
dictionary.most_common(20)
# Out:
# [('the', 69971),
#  ('of', 36412),
#  ('and', 28853),
#  ('to', 26158),
#  ('a', 23195),
#  ('in', 21337),
#  ('that', 10594),
#  ('is', 10109),
#  ('was', 9815),
#  ('he', 9548),
#  ('for', 9489),
#  ('it', 8760),
#  ('with', 7289),
#  ('as', 7253),
#  ('his', 6996),
#  ('on', 6741),
#  ('be', 6377),
#  ('at', 5372),
#  ('by', 5306),
#  ('i', 5164)]

# %%
language_model('the'), language_model('and'), language_model('was'), language_model('his')
# Out:
# ([0.07654280007513439,
#   0.311664926075615,
#   0.6876460379116297,
#   0.7650915050532642],
#  [0.06683788178378215,
#   0.1911394407780945,
#   0.47393305087123655,
#   0.918593292087268],
#  [0.015508655510261437, 0.2128328402366864, 0.5560382276281495, 0.95849609375],
#  [0.04520125692376297,
#   0.12654593902289119,
#   0.4016732468509118,
#   0.9478898510024183])

# %%
def keras_model(word):
    
    
    img=word[0]
    print(img)
    x=np.array(img)
    x=np.expand_dims(x,axis=0)

    #keras char model prediction
    predicted = model.predict(x)

    #character number 1
    letter = alphabet[np.argmax(predicted)] 
    
    img= word[1]
    x=np.array(img)
    x=np.expand_dims(x,axis=0)
    predicted2 = model.predict(x)

    letter2 = alphabet[np.argmax(predicted2)]

    img = word[2]
    x=np.array(img)
    x=np.expand_dims(x,axis=0)
    predicted3 = model.predict(x)


    letter3 = alphabet[np.argmax(predicted3)]
    
    return letter + letter2 + letter3

# %%
keras_model(braille_images[0])
# Out:
# <PIL.Image.Image image mode=RGB size=28x28 at 0x7FB4FA2859D0>
# WARNING:tensorflow:Model was constructed with shape (None, 28, 28, 3) for input Tensor("input_1:0", shape=(None, 28, 28, 3), dtype=float32), but it was called on an input with incompatible shape (None, 28, 29, 3).
# 'hjp'

# %%
def flatten(l):
    try:
        return flatten(l[0]) + (flatten(l[1:]) if len(l) > 1 else []) if type(l) is list else [l]
    except IndexError:
        return []

# %%
def model_function(word, beam_size):
    p1, p2, p3, p4 = language_model(word)
    paths = english_to_braille(word, test = True, show = False)
    #get the image
    item = paths[0]
    img=image.load_img(item)
    x=image.img_to_array(img)
    x=np.expand_dims(x,axis=0)

    #keras char model prediction
    predicted = model.predict(x)

    #character number 1

    probabilities = [predicted[0][i] for i in predicted.argsort()[0][-beam_size:][::-1]]
    letters = [alphabet[i] for i in predicted.argsort()[0][-beam_size:][::-1]]
    
    item = paths[1]
    img=image.load_img(item)
    x=image.img_to_array(img)
    x=np.expand_dims(x,axis=0)
    predicted2 = model.predict(x)

    probabilities2 = [predicted2[0][i] for i in predicted2.argsort()[0][-beam_size:][::-1]]
    letters2 = [alphabet[i] for i in predicted2.argsort()[0][-beam_size:][::-1]]

    item = paths[2]
    img=image.load_img(item)
    x=image.img_to_array(img)
    x=np.expand_dims(x,axis=0)
    predicted3 = model.predict(x)

    probabilities3 = [predicted3[0][i] for i in predicted3.argsort()[0][-beam_size:][::-1]]
    letters3 = [alphabet[i] for i in predicted3.argsort()[0][-beam_size:][::-1]]
    
    combos = [[[char+char2+char3+'</w>' for char in letters] for char2 in letters2] for char3 in letters3]
    combos = flatten(combos)
    keras_probabilities = []
    for comb in combos:
        first_char_prob = probabilities[letters.index(comb[0])]
        sec_char_prob = probabilities2[letters2.index(comb[1])]
        third_char_prob = probabilities3[letters3.index(comb[2])]
        keras_probabilities.append([first_char_prob, sec_char_prob, third_char_prob, 1])
    lm_probabilities = [language_model(i) for i in combos]
    
    
    joint_mult = []
    for index in range(len(lm_probabilities)):
        one = lm_probabilities[index][0] * keras_probabilities[index][0]
        two = lm_probabilities[index][1] * keras_probabilities[index][1]
        three = lm_probabilities[index][2]* keras_probabilities[index][2]
        fourth = lm_probabilities[index][3]* keras_probabilities[index][3]
        joint_mult.append(one * two * three * fourth)
    return combos[joint_mult.index(max(joint_mult))][:3]

# %%
from nltk.corpus import words
test = [word.lower() for word in words.words() if len(word) == 3]

# %%
len(test)
# Out:
# 1510

# %%
output = [model_function(word, 5) for word in test]

# %%
sum([output[i] == test[i] for i in range(len(test))])/len(test)
# Out:
# 0.1456953642384106

# %%
indexes = [i for i in range(len(test)) if output[i] == test[i] ]
correct = [output[i] for i in indexes]

# %%
keras_output = [keras_model(word) for word in test]

# %%
indexes_k = [i for i in range(len(test)) if keras_output[i] == test[i]]
correct_k = [keras_output[i] for i in indexes_k]

# %%
sum([keras_output[i] == test[i] for i in range(len(test))])/len(test)
# Out:
# 0.10662251655629139

# %%
# path = os.getcwd() + '/test_words/'
# #os.mkdir(path)

# def get_concat_h(im1, im2):
#     dst = Image.new('RGB', (im1.width + im2.width, im1.height))
#     dst.paste(im1, (0, 0))
#     dst.paste(im2, (im1.width, 0))
#     return dst

# for word in test:
#     img1 = Image.open(os.getcwd() + '/266 Photos/test/'+ word[0] + '.png')
#     img2 =  Image.open(os.getcwd() + '/266 Photos/test/' + word[1] + '.png')
#     img3 =  Image.open(os.getcwd() + '/266 Photos/test/'+ word[2] +'.png')
#     half_image = get_concat_h(img1, img2)
#     full_image = get_concat_h(half_image, img3)
#     full_image.save(path + word + '.png')

# %%
# path = os.getcwd() + '/test_words/'
# sentences, images = read_files(path)
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/Users/mariam/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3326, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-47-7772506f72fe>", line 2, in <module>
#     sentences, images = read_files(path)
#   File "<ipython-input-44-466c937eb662>", line 10, in read_files
#     img = Image.open(filename)
#   File "/Users/mariam/opt/anaconda3/lib/python3.7/site-packages/PIL/Image.py", line 2766, in open
# OSError: [Errno 24] Too many open files: '/Users/mariam/Desktop/266 Final Project/test_words/apa.png'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/mariam/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2040, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'OSError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/mariam/opt/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#   File "/Users/mariam/opt/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 319, in wrapped
#   File "/Users/mariam/opt/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 353, in _fixed_getinnerframes
#   File "/Users/mariam/opt/anaconda3/lib/python3.7/inspect.py", line 1502, in getinnerframes
#   File "/Users/mariam/opt/anaconda3/lib/python3.7/inspect.py", line 1460, in getframeinfo
#   File "/Users/mariam/opt/anaconda3/lib/python3.7/inspect.py", line 696, in getsourcefile
#   File "/Users/mariam/opt/anaconda3/lib/python3.7/inspect.py", line 725, in getmodule
#   File "/Users/mariam/opt/anaconda3/lib/python3.7/inspect.py", line 709, in getabsfile
#   File "/Users/mariam/opt/anaconda3/lib/python3.7/posixpath.py", line 383, in abspath
# OSError: [Errno 24] Too many open files
# ---------------------------------------------------------------------------

# %% [markdown]
# # EXAMPLE

# %%
#the = english_to_braille('the', test = False)

# %%
the = english_to_braille('the', test = True)
# Out:
# t
# h
# e

# %%
item = the[0]
img=image.load_img(item)
x=image.img_to_array(img)
x=np.expand_dims(x,axis=0)
predicted = model.predict(x)

probabilities = [predicted[0][i] for i in predicted.argsort()[0][-10:][::-1]]
letters = [alphabet[i] for i in predicted.argsort()[0][-10:][::-1]]
p_t = [laplaceUniCharCounts[char]/totalUni for char in letters]
p_t_times_p_ct = [probabilities[i] * p_t[i] for i in range(len(probabilities))]
letters

# %%
item = the[0]
img=image.load_img(item)
x=image.img_to_array(img)
x=np.expand_dims(x,axis=0)
predicted = model.predict(x)

probabilities = [predicted[0][i] for i in predicted.argsort()[0][-10:][::-1]]
letters = [alphabet[i] for i in predicted.argsort()[0][-10:][::-1]]
p_t = [laplaceUniCharCounts[char]/totalUni for char in letters]
p_t_times_p_ct = [probabilities[i] * p_t[i] for i in range(len(probabilities))]
letters
# Out:
# ['q', 's', 'r', 'n', 'g', 't', 'j', 'd', 'f', 'p']

# %%
item = the[1]
img=image.load_img(item)
x=image.img_to_array(img)
x=np.expand_dims(x,axis=0)
predicted2 = model.predict(x)

probabilities2 = [predicted2[0][i] for i in predicted2.argsort()[0][-10:][::-1]]
letters2 = [alphabet[i] for i in predicted2.argsort()[0][-10:][::-1]]


p_t2 = [[laplaceBiCharCounts[char+char2]/sum([value if key.startswith(char) 
                                              else 0 for key, value in laplaceBiCharCounts.items()]) for char in letters] for char2 in letters2]

p_t_times_p_ct2 = [[probabilities2[i] * p_t2[i][j] for i in range(len(probabilities2))] for j in range(len(p_t2[0]))]
letters2
# Out:
# ['r', 'h', 'g', 's', 'q', 'j', 'n', 'd', 'o', 't']

# %%
item = the[2]
img=image.load_img(item)
x=image.img_to_array(img)
x=np.expand_dims(x,axis=0)
predicted3 = model.predict(x)

probabilities3 = [predicted3[0][i] for i in predicted3.argsort()[0][-10:][::-1]]
letters3 = [alphabet[i] for i in predicted3.argsort()[0][-10:][::-1]]
#print(letters2)
p_t3 = []
for i in range(len(letters)):
    list_1 = []
    for j in range(len(letters2)):
        list_2 = []
        for k in range(len(letters3)):
            total = 0
            if laplaceTriCharCounts[letters[i]+letters2[j]+letters3[k]] != 0:
                for key, value in laplaceTriCharCounts.items():
                    if key.startswith(letters[i]+letters2[j]):
                        total += value 
            if total == 0:
                list_2.append(0)
            else:
                list_2.append(laplaceTriCharCounts[letters[i]+letters2[j]+letters3[k]]/total)
        
        list_1.append(list_2)    
    p_t3.append(list_1)


p_t_times_p_ct3 = [[[probabilities3[i] * p_t3[i][j][k] for i in range(len(p_t3))] for j in range(len(p_t3[0]))] for k in range(len(p_t3[0][0]))]
letters3
# Out:
# ['o', 'r', 'c', 'h', 's', 'z', 'k', 'n', 'g', 'e']

# %%
res= [[[p_t_times_p_ct3[i][j][k] * 
   p_t_times_p_ct2[i][j] *
   p_t_times_p_ct[i] 
   for i in range(len(p_t_times_p_ct))] for j in range(len(p_t_times_p_ct2))] for k in range(len(p_t_times_p_ct3))]

# %%
combos = [[[char+char2+char3 for char in letters] for char2 in letters2] for char3 in letters3]

# %%
np.amax(res), np.where(res == np.amax(res))
# Out:
# (3.866040719349266e-11, (array([1]), array([0]), array([4])))

# %%
combos[1][0][4]
# Out:
# 'grr'

# %%
from tensorflow.keras.preprocessing import image
img=image.load_img( os.getcwd() + '/archive/Braille Dataset/Braille Dataset/a1.JPG0dim.jpg')
plt.imshow(img)
x=image.img_to_array(img)
print(x.shape)
x=np.expand_dims(x,axis=0)
model.predict(x)
a=np.argmax(model.predict(x), axis=1)
alphabet[a[0]]
# Out:
# (28, 28, 3)
# 'a'

# %%
from scipy import ndimage, misc

# %%
img = image.load_img( os.getcwd() + '/266 Photos/test/a.png')
plt.imshow(img)
x= image.img_to_array(img)
print(x.shape)
x = resize(x, (28,28,3))
print(x.shape)
x=np.expand_dims(x,axis=0)
model.predict(x)
a=np.argmax(model.predict(x), axis=1)
alphabet[a[0]]
# Out:
# (28, 28, 3)
# (28, 28, 3)
# 'b'

# %%
img = image.load_img( os.getcwd() + '/266 Photos/test/m.png')
plt.imshow(img)
x= image.img_to_array(img)
print(x.shape)
x = resize(x, (28,28,3))
print(x.shape)
x=np.expand_dims(x,axis=0)
model.predict(x)
a=np.argmax(model.predict(x), axis=1)
alphabet[a[0]]
# Out:
# (28, 28, 3)
# (28, 28, 3)
# 's'
